# %%
import os
from dotenv import load_dotenv
load_dotenv()

api_key = os.getenv("OPENAI_API_KEY")

from langchain_core.prompts import ChatPromptTemplate
from langchain_openai import ChatOpenAI
from langchain_core.output_parsers import StrOutputParser

prompt = ChatPromptTemplate.from_template(
    "주어지는 문구에 대하여 50자 이내의 짧은 시를 작성해주세요: {word}"
)

model = ChatOpenAI(model="gpt-5-mini")
parser = StrOutputParser()

chain = prompt | model | parser

result = chain.invoke({"word": "평범한 일상"})
print(result)
# Out:
# 평범한 하루 창가에 햇빛 한줌

# %%
# Create a LANGSMITH_API_KEY in Settings > API Keys
from langsmith import Client
client = Client(api_key="LANGSMITH_API_KEY")
prompt = client.pull_prompt("rlm/rag-prompt", include_model=True)
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# File c:\work\ai_prj\.venv\Lib\site-packages\langsmith\utils.py:159, in raise_for_status_with_text(response)
#     158 try:
# --> 159     response.raise_for_status()
#     160 except requests.HTTPError as e:
#
# File c:\work\ai_prj\.venv\Lib\site-packages\requests\models.py:1026, in Response.raise_for_status(self)
#    1025 if http_error_msg:
# -> 1026     raise HTTPError(http_error_msg, response=self)
#
# HTTPError: 403 Client Error: Forbidden for url: https://api.smith.langchain.com/commits/rlm/rag-prompt/latest?include_model=true
#
# The above exception was the direct cause of the following exception:
#
# HTTPError                                 Traceback (most recent call last)
# File c:\work\ai_prj\.venv\Lib\site-packages\langsmith\client.py:952, in Client.request_with_retries(self, method, pathname, request_kwargs, stop_after_attempt, retry_on, to_ignore, handle_response, _context, **kwargs)
#     946     response = self.session.request(
#     947         method,
#     948         _construct_url(self.api_url, pathname),
#     949         stream=False,
#     950         **request_kwargs,
#     951     )
# --> 952 ls_utils.raise_for_status_with_text(response)
#     953 return response
#
# File c:\work\ai_prj\.venv\Lib\site-packages\langsmith\utils.py:161, in raise_for_status_with_text(response)
#     160 except requests.HTTPError as e:
# --> 161     raise requests.HTTPError(str(e), response.text) from e  # type: ignore[call-arg]
#     162 except httpx.HTTPStatusError as e:
#
# HTTPError: [Errno 403 Client Error: Forbidden for url: https://api.smith.langchain.com/commits/rlm/rag-prompt/latest?include_model=true] {"error":"Forbidden"}
#
#
# During handling of the above exception, another exception occurred:
#
# LangSmithError                            Traceback (most recent call last)
# Cell In[9], line 4
#       2 from langsmith import Client
#       3 client = Client(api_key="LANGSMITH_API_KEY")
# ----> 4 prompt = client.pull_prompt("rlm/rag-prompt", include_model=True)
#
# File c:\work\ai_prj\.venv\Lib\site-packages\langsmith\client.py:7740, in Client.pull_prompt(self, prompt_identifier, include_model)
#    7736     @contextlib.contextmanager
#    7737     def suppress_langchain_beta_warning():
#    7738         yield
# -> 7740 prompt_object = self.pull_prompt_commit(
#    7741     prompt_identifier, include_model=include_model
#    7742 )
#    7743 with suppress_langchain_beta_warning():
#    7744     prompt = loads(json.dumps(prompt_object.manifest))
#
# File c:\work\ai_prj\.venv\Lib\site-packages\langsmith\client.py:7639, in Client.pull_prompt_commit(self, prompt_identifier, include_model)
#    7625 """Pull a prompt object from the LangSmith API.
#    7626
#    7627 Args:
#    (...)   7634     ValueError: If no commits are found for the prompt.
#    7635 """
#    7636 owner, prompt_name, commit_hash = ls_utils.parse_prompt_identifier(
#    7637     prompt_identifier
#    7638 )
# -> 7639 response = self.request_with_retries(
#    7640     "GET",
#    7641     (
#    7642         f"/commits/{owner}/{prompt_name}/{commit_hash}"
#    7643         f"{'?include_model=true' if include_model else ''}"
#    7644     ),
#    7645 )
#    7646 return ls_schemas.PromptCommit(
#    7647     **{"owner": owner, "repo": prompt_name, **response.json()}
#    7648 )
#
# File c:\work\ai_prj\.venv\Lib\site-packages\langsmith\client.py:1012, in Client.request_with_retries(self, method, pathname, request_kwargs, stop_after_attempt, retry_on, to_ignore, handle_response, _context, **kwargs)
#    1010     except (ValueError, KeyError):
#    1011         pass
# -> 1012     raise ls_utils.LangSmithError(
#    1013         f"Failed to {method} {pathname} in LangSmith"
#    1014         f" API. {repr(e)}"
#    1015     )
#    1016 else:
#    1017     raise ls_utils.LangSmithError(
#    1018         f"Failed to {method} {pathname} in LangSmith"
#    1019         f" API. {repr(e)}"
#    1020     )
#
# LangSmithError: Failed to GET /commits/rlm/rag-prompt/latest?include_model=true in LangSmith API. HTTPError('403 Client Error: Forbidden for url: https://api.smith.langchain.com/commits/rlm/rag-prompt/latest?include_model=true', '{"error":"Forbidden"}\n')
